level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_32b34_level0_col1" class="col_heading level0 col1" >CCA3</th>
#       <th id="T_32b34_level0_col2" class="col_heading level0 col2" >Country/Territory</th>
#       <th id="T_32b34_level0_col3" class="col_heading level0 col3" >Capital</th>
#       <th id="T_32b34_level0_col4" class="col_heading level0 col4" >Continent</th>
#       <th id="T_32b34_level0_col5" class="col_heading level0 col5" >2022 Population</th>
#       <th id="T_32b34_level0_col6" class="col_heading level0 col6" >2020 Population</th>
#       <th id="T_32b34_level0_col7" class="col_heading level0 col7" >2015 Population</th>
#       <th id="T_32b34_level0_col8" class="col_heading level0 col8" >2010 Population</th>
#       <th id="T_32b34_level0_col9" class="col_heading level0 col9" >2000 Population</th>
#       <th id="T_32b34_level0_col10" class="col_heading level0 col10" >1990 Population</th>
#       <th id="T_32b34_level0_col11" class="col_heading level0 col11" >1980 Population</th>
#       <th id="T_32b34_level0_col12" class="col_heading level0 col12" >1970 Population</th>
#       <th id="T_32b34_level0_col13" class="col_heading level0 col13" >Area (km²)</th>
#       <th id="T_32b34_level0_col14" class="col_heading level0 col14" >Density (per km²)</th>
#       <th id="T_32b34_level0_col15" class="col_heading level0 col15" >Growth Rate</th>
#       <th id="T_32b34_level0_col16" class="col_heading level0 col16" >World Population Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_32b34_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_32b34_row0_col0" class="data row0 col0" >36</td>
#       <td id="T_32b34_row0_col1" class="data row0 col1" >AFG</td>
#       <td id="T_32b34_row0_col2" class="data row0 col2" >Afghanistan</td>
#       <td id="T_32b34_row0_col3" class="data row0 col3" >Kabul</td>
#       <td id="T_32b34_row0_col4" class="data row0 col4" >Asia</td>
#       <td id="T_32b34_row0_col5" class="data row0 col5" >41128771</td>
#       <td id="T_32b34_row0_col6" class="data row0 col6" >38972230</td>
#       <td id="T_32b34_row0_col7" class="data row0 col7" >33753499</td>
#       <td id="T_32b34_row0_col8" class="data row0 col8" >28189672</td>
#       <td id="T_32b34_row0_col9" class="data row0 col9" >19542982</td>
#       <td id="T_32b34_row0_col10" class="data row0 col10" >10694796</td>
#       <td id="T_32b34_row0_col11" class="data row0 col11" >12486631</td>
#       <td id="T_32b34_row0_col12" class="data row0 col12" >10752971</td>
#       <td id="T_32b34_row0_col13" class="data row0 col13" >652230</td>
#       <td id="T_32b34_row0_col14" class="data row0 col14" >63.058700</td>
#       <td id="T_32b34_row0_col15" class="data row0 col15" >1.025700</td>
#       <td id="T_32b34_row0_col16" class="data row0 col16" >0.520000</td>
#     </tr>
#     <tr>
#       <th id="T_32b34_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_32b34_row1_col0" class="data row1 col0" >138</td>
#       <td id="T_32b34_row1_col1" class="data row1 col1" >ALB</td>
#       <td id="T_32b34_row1_col2" class="data row1 col2" >Albania</td>
#       <td id="T_32b34_row1_col3" class="data row1 col3" >Tirana</td>
#       <td id="T_32b34_row1_col4" class="data row1 col4" >Europe</td>
#       <td id="T_32b34_row1_col5" class="data row1 col5" >2842321</td>
#       <td id="T_32b34_row1_col6" class="data row1 col6" >2866849</td>
#       <td id="T_32b34_row1_col7" class="data row1 col7" >2882481</td>
#       <td id="T_32b34_row1_col8" class="data row1 col8" >2913399</td>
#       <td id="T_32b34_row1_col9" class="data row1 col9" >3182021</td>
#       <td id="T_32b34_row1_col10" class="data row1 col10" >3295066</td>
#       <td id="T_32b34_row1_col11" class="data row1 col11" >2941651</td>
#       <td id="T_32b34_row1_col12" class="data row1 col12" >2324731</td>
#       <td id="T_32b34_row1_col13" class="data row1 col13" >28748</td>
#       <td id="T_32b34_row1_col14" class="data row1 col14" >98.870200</td>
#       <td id="T_32b34_row1_col15" class="data row1 col15" >0.995700</td>
#       <td id="T_32b34_row1_col16" class="data row1 col16" >0.040000</td>
#     </tr>
#     <tr>
#       <th id="T_32b34_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_32b34_row2_col0" class="data row2 col0" >34</td>
#       <td id="T_32b34_row2_col1" class="data row2 col1" >DZA</td>
#       <td id="T_32b34_row2_col2" class="data row2 col2" >Algeria</td>
#       <td id="T_32b34_row2_col3" class="data row2 col3" >Algiers</td>
#       <td id="T_32b34_row2_col4" class="data row2 col4" >Africa</td>
#       <td id="T_32b34_row2_col5" class="data row2 col5" >44903225</td>
#       <td id="T_32b34_row2_col6" class="data row2 col6" >43451666</td>
#       <td id="T_32b34_row2_col7" class="data row2 col7" >39543154</td>
#       <td id="T_32b34_row2_col8" class="data row2 col8" >35856344</td>
#       <td id="T_32b34_row2_col9" class="data row2 col9" >30774621</td>
#       <td id="T_32b34_row2_col10" class="data row2 col10" >25518074</td>
#       <td id="T_32b34_row2_col11" class="data row2 col11" >18739378</td>
#       <td id="T_32b34_row2_col12" class="data row2 col12" >13795915</td>
#       <td id="T_32b34_row2_col13" class="data row2 col13" >2381741</td>
#       <td id="T_32b34_row2_col14" class="data row2 col14" >18.853100</td>
#       <td id="T_32b34_row2_col15" class="data row2 col15" >1.016400</td>
#       <td id="T_32b34_row2_col16" class="data row2 col16" >0.560000</td>
#     </tr>
#     <tr>
#       <th id="T_32b34_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_32b34_row3_col0" class="data row3 col0" >213</td>
#       <td id="T_32b34_row3_col1" class="data row3 col1" >ASM</td>
#       <td id="T_32b34_row3_col2" class="data row3 col2" >American Samoa</td>
#       <td id="T_32b34_row3_col3" class="data row3 col3" >Pago Pago</td>
#       <td id="T_32b34_row3_col4" class="data row3 col4" >Oceania</td>
#       <td id="T_32b34_row3_col5" class="data row3 col5" >44273</td>
#       <td id="T_32b34_row3_col6" class="data row3 col6" >46189</td>
#       <td id="T_32b34_row3_col7" class="data row3 col7" >51368

# %%
print(f"Informations Of The Dataset :\n")
print(df.info())
# Out:
# Informations Of The Dataset :
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country/Territory            234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              234 non-null    int64
#  6   2020 Population              234 non-null    int64
#  7   2015 Population              234 non-null    int64
#  8   2010 Population              234 non-null    int64
#  9   2000 Population              234 non-null    int64
#  10  1990 Population              234 non-null    int64
#  11  1980 Population              234 non-null    int64
#  12  1970 Population              234 non-null    int64
#  13  Area (km²)                   234 non-null    int64
#  14  Density (per km²)            234 non-null    float64
#  15  Growth Rate                  234 non-null    float64
#  16  World Population Percentage  234 non-null    float64
# dtypes: float64(3), int64(10), object(4)
# memory usage: 31.2+ KB
# None

# %%
print(f"Summary Of The Dataset :")
df.describe().style.set_properties(**{"background-color": "#006837","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# Summary Of The Dataset :
# <style type="text/css">
# #T_b3193_row0_col0, #T_b3193_row0_col1, #T_b3193_row0_col2, #T_b3193_row0_col3, #T_b3193_row0_col4, #T_b3193_row0_col5, #T_b3193_row0_col6, #T_b3193_row0_col7, #T_b3193_row0_col8, #T_b3193_row0_col9, #T_b3193_row0_col10, #T_b3193_row0_col11, #T_b3193_row0_col12, #T_b3193_row1_col0, #T_b3193_row1_col1, #T_b3193_row1_col2, #T_b3193_row1_col3, #T_b3193_row1_col4, #T_b3193_row1_col5, #T_b3193_row1_col6, #T_b3193_row1_
level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_b3193_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_b3193_row3_col1" class="data row3 col1" >510.000000</td>
#       <td id="T_b3193_row3_col2" class="data row3 col2" >520.000000</td>
#       <td id="T_b3193_row3_col3" class="data row3 col3" >564.000000</td>
#       <td id="T_b3193_row3_col4" class="data row3 col4" >596.000000</td>
#       <td id="T_b3193_row3_col5" class="data row3 col5" >651.000000</td>
#       <td id="T_b3193_row3_col6" class="data row3 col6" >700.000000</td>
#       <td id="T_b3193_row3_col7" class="data row3 col7" >733.000000</td>
#       <td id="T_b3193_row3_col8" class="data row3 col8" >752.000000</td>
#       <td id="T_b3193_row3_col9" class="data row3 col9" >1.000000</td>
#       <td id="T_b3193_row3_col10" class="data row3 col10" >0.026100</td>
#       <td id="T_b3193_row3_col11" class="data row3 col11" >0.912000</td>
#       <td id="T_b3193_row3_col12" class="data row3 col12" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b3193_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_b3193_row4_col0" class="data row4 col0" >59.250000</td>
#       <td id="T_b3193_row4_col1" class="data row4 col1"

# %%
df.describe(include=object).T.style.set_properties(**{"background-color": "#006837","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# <style type="text/css">
# #T_2c4f6_row0_col0, #T_2c4f6_row0_col1, #T_2c4f6_row0_col2, #T_2c4f6_row0_col3, #T_2c4f6_row1_col0, #T_2c4f6_row1_col1, #T_2c4f6_row1_col2, #T_2c4f6_row1_col3, #T_2c4f6_row2_col0, #T_2c4f6_row2_col1, #T_2c4f6_row2_col2, #T_2c4f6_row2_col3, #T_2c4f6_row3_col0, #T_2c4f6_row3_col1, #T_2c4f6_row3_col2, #T_2c4f6_row3_col3 {
#   background-color: #006837;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_2c4f6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2c4f6_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_2c4f6_level0_col1" class="col_heading level0 col1" >unique</th>
#       <th id="T_2c4f6_level0_col2" class="col_heading level0 col2" >top</th>
#       <th id="T_2c4f6_level0_col3" class="col_heading level0 col3" >freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c4f6_level0_row0" class="row_heading level0 row0" >CCA3</th>
#       <td id="T_2c4f6_row0_col0" class="data row0 col0" >234</td>
#       <td id="T_2c4f6_row0_col1" class="data row0 col1" >234</td>
#       <td id="T_2c4f6_row0_col2" class="data row0 col2" >AFG</td>
#       <td id="T_2c4f6_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2c4f6_level0_row1" class="row_heading level0 row1" >Country/Territory</th>
#       <td id="T_2c4f6_row1_col0" class="data row1 col0" >234</td>
#       <td id="T_2c4f6_row1_col1" class="data row1 col1" >234</td>
#       <td id="T_2c4f6_row1_col2" class="data row1 col2" >Afghanistan</td>
#       <td id="T_2c4f6_row1_col3" class="data row1 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2c4f6_level0_row2" class="row_heading level0 row2" >Capital</th>
#       <td id="T_2c4f6_row2_col0" class="data row2 col0" >234</td>
#       <td id="T_2c4f6_row2_col1" class="data row2 col1" >234</td>
#       <td id="T_2c4f6_row2_col2" class="data row2 col2" >Kabul</td>
#       <td id="T_2c4f6_row2_col3" class="data row2 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2c4f6_level0_row3" class="row_heading level0 row3" >Continent</th>
#       <td id="T_2c4f6_row3_col0" class="data row3 col0" >234</td>
#       <td id="T_2c4f6_row3_col1" class="data row3 col1" >6</td>
#       <td id="T_2c4f6_row3_col2" class="data row3 col2" >Africa</td>
#       <td id="T_2c4f6_row3_col3" class="data row3 col3" >57</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(f"Null values of the Dataset :")
df.isna().sum().to_frame().T.style.set_properties(**{"background-color": "#006837","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# Null values of the Dataset :
# <style type="text/css">
# #T_5c9c1_row0_col0, #T_5c9c1_row0_col1, #T_5c9c1_row0_col2, #T_5c9c1_row0_col3, #T_5c9c1_row0_col4, #T_5c9c1_row0_col5, #T_5c9c1_row0_col6, #T_5c9c1_row0_col7, #T_5c9c1_row0_col8, #T_5c9c1_row0_col9, #T_5c9c1_row0_col10, #T_5c9c1_row0_col11, #T_5c9c1_row0_col12, #T_5c9c1_row0_col13, #T_5c9c1_row0_col14, #T_5c9c1_row0_col15, #T_5c9c1_row0_col16 {
#   background-color: #006837;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_5c9c1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5c9c1_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_5c9c1_level0_col1" class="col_heading level0 col1" >CCA3</th>
#       <th id="T_5c9c1_level0_col2" class="col_heading level0 col2" >Country/Territory</th>
#       <th id="T_5c9c1_level0_col3" class="col_heading level0 col3" >Capital</th>
#       <th id="T_5c9c1_level0_col4" class="col_heading level0 col4" >Continent</th>
#       <th id="T_5c9c1_level0_col5" class="col_heading level0 col5" >2022 Population</th>
#       <th id="T_5c9c1_level0_col6" class="col_heading level0 col6" >2020 Population</th>
#       <th id="T_5c9c1_level0_col7" class="col_heading level0 col7" >2015 Population</th>
#       <th id="T_5c9c1_level0_col8" class="col_heading level0 col8" >2010 Population</th>
#       <th id="T_5c9c1_level0_col9" class="col_heading level0 col9" >2000 Population</th>
#       <th id="T_5c9c1_level0_col10" class="col_heading level0 col10" >1990 Population</th>
#       <th id="T_5c9c1_level0_col11" class="col_heading level0 col11" >1980 Population</th>
#       <th id="T_5c9c1_level0_col12" class="col_heading level0 col12" >1970 Population</th>
#       <th id="T_5c9c1_level0_col13" class="col_heading level0 col13" >Area (km²)</th>
#       <th id="T_5c9c1_level0_col14" class="col_heading level0 col14" >Density (per km²)</th>
#       <th id="T_5c9c1_level0_col15" class="col_heading level0 col15" >Growth Rate</th>
#       <th id="T_5c9c1_level0_col16" class="col_heading level0 col16" >World Population Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c9c1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5c9c1_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_5c9c1_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_5c9c1_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_5c9c1_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_5c9c1_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_5c9c1_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_5c9c1_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_5c9c1_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_5c9c1_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_5c9c1_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_5c9c1_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_5c9c1_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_5c9c1_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_5c9c1_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_5c9c1_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_5c9c1_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_5c9c1_row0_col16" class="data row0 col16" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.set_style("white")
sns.set(rc={"axes.facecolor":"#D5CE98","figure.facecolor":"#D5CE98"})
sns.set_context("poster",font_scale = .7)

palette = ["#006837","#1A9850","#66BD63","#A6D96A","#D9EF8B","#FFFFBF","#FEE08B","#FDAE61","#F46D43","#D73027","#A50026"]
palette_cmap = ["#A50026","#D73027","#F46D43","#FDAE61","#FEE08B","#FFFFBF","#D9EF8B","#A6D96A","#66BD63","#1A9850","#006837"]

 #sns.palplot(sns.color_palette(palette))
#sns.palplot(sns.color_palette(palette_cmap))
#plt.show()

# %%
print(f"Let's have a look on the population :")
_, axs = plt.subplots(2,1,figsize=(20,16))
plt.tight_layout(pad=7.0)

sns.barplot(x=data["Country/Territory"],y=data["2022 Population"],order=data.sort_values("2022 Population",ascending=True)["Country/Territory"][:11],ax=axs[0],palette=palette, saturation=1,edgecolor = "#1c1c1c", linewidth = 4)
   axs[0].set_yscale("linear")
   axs[0].set_title("Least Populated Countries In 2022",fontsize=25)
   axs[0].set_xlabel("\nCountry",fontsize=20)
   axs[0].set_ylabel("Population",fontsize=20)
   axs[0].set_xticklabels(axs[0].get_xticklabels(),rotation = 12)
for container in axs[0].containers:





 axs[0].bar_label(container,label_type="center",padding=6,size=18,color="black",rotation=0,
bbox={"boxstyle": "round", "pad": 0.4, "facecolor": "orange", "edgecolor": "#1c1c1c", "linewidth" : 3, "alpha": 1})


ns.barplot(x=data["Country/Territory"],y=data["2022 Population"],order=data.sort_values("2022 Population",ascending=False)["Country/Territory"][:11],ax=axs[1],palette=palette, saturation=1,edgecolor = "#1c1c1c", linewidth = 4)
 axs[1].set_yscale("log")
 axs[1].set_title("Top Populated Countries In 2022",fontsize=25)
 axs[1].set_xlabel("\nCountry",fontsize=20)
 axs[1].set_ylabel("Population",fontsize=20)
 axs[1].set_xticklabels(axs[1].get_xticklabels(),rotation = 0)
for container in axs[1].containers:
 axs[1].bar_label(container,label_type="edge",padding=6,size=18,color="black",rotation=0,
bbox={"boxstyle": "round", "pad": 0.4, "facecolor": "orange", "edgecolor": "#1c1c1c", "linewidth" : 3, "alpha": 1})


sns.despine(left=True, bottom=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndentationError                          Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/compilerop.py in ast_parse(self, source, filename, symbol)
#      99         Arguments are exactly the same as ast.parse (in the standard library),
#     100         and are passed to the built-in compile function."""
# --> 101         return compile(source, filename, symbol, self.flags | PyCF_ONLY_AST, 1)
#     102
#     103     def reset_compiler_flags(self):
#
# IndentationError: unexpected indent (<ipython-input-45-357bc95ead77>, line 6)

# %%
print(f"Let's have a look on the population :")
_, axs = plt.subplots(2,1,figsize=(20,16))
plt.tight_layout(pad=7.0)

sns.barplot(x=df["Country/Territory"],y=df["2022 Population"],order=df.sort_values("2022 Population",ascending=True)["Country/Territory"][:11],ax=axs[0],palette=palette, saturation=1,edgecolor = "#1c1c1c", linewidth = 4)
axs[0].set_yscale("linear")
axs[0].set_title("Least Populated Countries In 2022",fontsize=25)
axs[0].set_xlabel("\nCountry",fontsize=20)
axs[0].set_ylabel("Population",fontsize=20)
axs[0].set_xticklabels(axs[0].get_xticklabels(),rotation = 12)
for container in axs[0].containers:





      axs[0].bar_label(container,label_type="center",padding=6,size=18,color="black",rotation=0,
bbox={"boxstyle": "round", "pad": 0.4, "facecolor": "orange", "edgecolor": "#1c1c1c", "linewidth" : 3, "alpha": 1})

sns.barplot(x=df["Country/Territory"],y=df["2022 Population"],order=df.sort_values("2022 Population",ascending=False)["Country/Territory"])
# Out:
# Let's have a look on the population :
# <Axes: xlabel='Country/Territory', ylabel='2022 Population'>
